# %% [markdown]
# # Your Data Analysis Project
#
# ## Part A - Data Preparation
#
# |                         |                                                               |
# |------------------------:|:--------------------------------------------------------------|
# | **Job Code**            | 123456                                                        |
# | **Job Name**            | Your Job Name                         |
# | **Mission Team**        | Mission Team Name                |
# | **Data Analysis Plan**  | DM#123456                                                    |
# | **Source Code Repo.**   | Link to a GitLab repository or a folder in shared drive             |
# | **Description**         | Describe what this notebook does. |
# | **Data Analyst**        | Your name, title, center                                 |

# %%
# Import required Python modules

import pandas as pd

# %%
# Set up Constant Values

INPUT_FILE = "World_Development_Indicators.csv"
OUTPUT_FILE = "WDI_Cleansed.xlsx"

# %%
# Program execution start time

# %% [markdown]
# ## Step 1 - Load and Know the Input Dataset

# %%
# Step 1 Python code

# %% [markdown]
# ## Step 2 - Check Data Quality and Fix Issues
#
# Data reliability is a critical component of data analysis. GAO guideline calls for electronic data reliability test.
# We will check for missing values, duplicate records, extreme values (outliers), and other abnormality in the source data.

# %%
# Check for missing values

# %%
# Check for duplicate records

# %%
# Check for extreme values in numerical variables

# %%
# Check for abnormality in categorical variables such as misspelled or missing categories

# %%
# Check for imbalance in distribution of categories

# %% [markdown]
# ## Step 3 - Prepare Dataset for Analysis
#
# After data quality checking and data cleansing, we use various techniques to prepare a final dataset for analysis.
#
# These technique may include the following:
#
# - Select population of interest by filtering the dataset
# - Select variables of interest
# - Rename or transform variables
# - Derive new variables from existing variables

# %%
# Python code here

# %% [markdown]
# ## Step 4 - Save the Cleansed Dataset

# %%
# Create the cover sheet data frame

# %%
# Save both the cover sheet and cleansed data to an Excel file

# %%
# Generate Hash

# %%
# Program execution end time and elapsed time

# %% [markdown]
# The End
